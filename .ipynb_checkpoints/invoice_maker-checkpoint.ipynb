# %%
import pandas as pd
import numpy as np
import random
import os

# %%
folder_path = r"C:\Users\lukas\OneDrive\Data Analyst Project Portfolio\MedTech Company"
file_path = folder_path + '\dims'
files = os.listdir(file_path)

# %%
print(folder_path)
print(files)
# Out:
# C:\Users\lukas\OneDrive\Data Analyst Project Portfolio\MedTech Company
# ['dim_customers.xlsx', 'dim_product_info.xlsx', 'dim_region_info.xlsx']

# %%
data_dict = {}

# %%
for filename in os.listdir(file_path):
    print(filename)
    if filename.endswith(".xlsx"):
        file_path = os.path.join(file_path, filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 for filename in os.listdir(file_path):
#       2     print(filename)
#       3     if filename.endswith(".xlsx"):
#
# FileNotFoundError: [WinError 3] System nie może odnaleźć określonej ścieżki: 'C:\\Users\\lukas\\OneDrive\\Data Analyst Project Portfolio\\MedTech Company\\dims\\dim_customers.xlsx\\dim_product_info.xlsx\\dim_region_info.xlsx'
